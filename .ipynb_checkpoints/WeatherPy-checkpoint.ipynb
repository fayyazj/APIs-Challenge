# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
from pprint import pprint

# Import OpenWeather API Key and "mask" it
from api_keys import api_key
api_key = f'&APPID={api_key}'

#base url for API call
url = 'http://api.openweathermap.org/data/2.5/weather?q=' + api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 585

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Printing to the API call logger
print('Beginning Data Retreival')
print('------------------------')

weather_url = 'http://api.openweathermap.org/data/2.5/weather?q=' 

# Initialize Lists for the Data Frame
New_Cities = []
Clouds = []
Dates = []
Humidities = []
Latitudes = []
Longitudes = []
Max_Temps = []
Wind_Speeds = []
Countries = []

# Initialize Counts
count_one = 0
set_one = 1

# Creating Data Frame Columns
for city in cities:
    try:
        response = requests.get(weather_url + city + api_key).json()
        Clouds.append(response['clouds']['all'])
        Countries.append(response['sys']['country'])
        Dates.append(response['dt'])
        Humidities.append(response['main']['humidity'])
        Latitudes.append(response['coord']['lat'])
        Longitudes.append(response['coord']['lon'])
        Max_Temps.append(response['main']['temp_max'])
        Wind_Speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            New_Cities.append(city)
        else:
            count_one += 1
            New_Cities.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")

print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
# Out:
# Beginning Data Retreival
# ------------------------
# Processing Record 1 of Set 1 | leningradskiy
# Processing Record 2 of Set 1 | aklavik
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | sao joao da barra
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | fortuna
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | nortelandia
# Processing Record 15 of Set 1 | kirksville
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | los llanos de aridane
# Processing Record 20 of Set 1 | ormara
# Processing Record 21 of Set 1 | dunedin
# Processing Record 22 of Set 1 | bonavista
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | itarema
# Processing Record 25 of Set 1 | barabai
# Processing Record 26 of Set 1 | mehamn
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | mandera
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | yanam
# Processing Record 32 of Set 1 | high level
# Processing Record 33 of Set 1 | san patricio
# Processing Record 34 of Set 1 | avera
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | dingle
# Processing Record 37 of Set 1 | teguise
# Processing Record 38 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | lagoa
# Processing Record 42 of Set 1 | beloha
# Processing Record 43 of Set 1 | cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 1 | hambantota
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | port lincoln
# Processing Record 47 of Set 1 | ballina
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | barrow
# City not found. Skipping...
# Processing Record 2 of Set 2 | bay roberts
# Processing Record 3 of Set 2 | sainte-claire
# Processing Record 4 of Set 2 | jefferson city
# Processing Record 5 of Set 2 | kayes
# City not found. Skipping...
# Processing Record 6 of Set 2 | jutai
# Processing Record 7 of Set 2 | pevek
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | whyalla
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | imeni poliny osipenko
# Processing Record 13 of Set 2 | port arthur
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | linjiang
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | qaqortoq
# City not found. Skipping...
# Processing Record 19 of Set 2 | kananga
# Processing Record 20 of Set 2 | georgetown
# City not found. Skipping...
# Processing Record

# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 3 | castro
# City not found. Skipping...
# Processing Record 46 of Set 3 | ibra
# Processing Record 47 of Set 3 | meulaboh
# Processing Record 48 of Set 3 | kimbe
# Processing Record 49 of Set 3 | norman wells
# Processing Record 1 of Set 4 | nouakchott
# Processing Record 2 of Set 4 | new norfolk
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | nome
# Processing Record 6 of Set 4 | anadyr
# Processing Record 7 of Set 4 | keetmanshoop
# Processing Record 8 of Set 4 | kidodi
# Processing Record 9 of Set 4 | boralday
# Processing Record 10 of Set 4 | north bend
# Processing Record 11 of Set 4 | lucea
# Processing Record 12 of Set 4 | lossiemouth
# Processing Record 13 of Set 4 | jamestown
# Processing Record 14 of Set 4 | lasa
# Processing Record 15 of Set 4 | riyadh
# Processing Record 16 of Set 4 | severo-kurilsk
# Processing Record 17 of Set 4 | massakory
# City not found. Skipping...
# Processing Record 18 of Set 4 | liptovsky mikulas
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | kosh-agach
# Processing Record 21 of Set 4 | kodiak
# City not found. Skipping...
# Processing Record 22 of Set 4 | ahuimanu
# Processing Record 23 of Set 4 | anaconda
# Processing Record 24 of Set 4 | omboue
# Processing Record 25 of Set 4 | nemuro
# Processing Record 26 of Set 4 | bethel
# Processing Record 27 of Set 4 | shenandoah
# Processing Record 28 of Set 4 | vung tau
# Processing Record 29 of Set 4 | abashiri
# Processing Record 30 of Set 4 | tessalit
# Processing Record 31 of Set 4 | santa marinella
# Processing Record 32 of Set 4 | praia da vitoria
# Processing Record 33 of Set 4 | okakarara
# Processing Record 34 of Set 4 | husavik
# City not found. Skipping...
# Processing Record 35 of Set 4 | tucuman
# Processing Record 36 of Set 4 | seabra
# City not found. Skipping...
# Processing Record 37 of Set 4 | thompson
# Processing Record 38 of Set 4 | broome
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | fukue
# Processing Record 41 of Set 4 | butaritari
# Processing Record 42 of Set 4 | batticaloa
# Processing Record 43 of Set 4 | kununurra
# Processing Record 44 of Set 4 | tarko-sale
# Processing Record 45 of Set 4 | syracuse
# Processing Record 46 of Set 4 | quang ngai
# Processing Record 47 of Set 4 | waingapu
# Processing Record 48 of Set 4 | formosa
# Processing Record 49 of Set 4 | black river
# City not found. Skipping...
# Processing Record 1 of Set 5 | moshi
# Processing Record 2 of Set 5 | gushi
# Processing Record 3 of Set 5 | boa vista
# Processing Record 4 of Set 5 | chiredzi
# Processing Record 5 of Set 5 | togul
# Processing Record 6 of Set 5 | namatanai
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | tomatlan
# Processing Record 9 of Set 5 | powell river
# Processing Record 10 of Set 5 | caceres
# Processing Record 11 of Set 5 | ploemeur
# City not found. Skipping...
# Processing Record 12 of Set 5 | hithadhoo
# Processing Record 13 of Set 5 | pizhanka
# Processing Record 14 of Set 5 | becej
# Processing Record 15 of Set 5 | half moon bay
# Processing Record 16 of Set 5 | caravelas
# Processing Record 17 of Set 5 | saint-augustin
# Processing Record 18 of Set 5 | zwedru
# Processing Record 19 of Set 5 | simao
# Processing Record 20 of Set 5 | nishihara
# Processing Record 21 of Set 5 | broken hill
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | mount gambier
# Processing Record 24 of Set 5 | port blair
# Processing Record 25 of Set 5 | fort-shevchenko
# Processing Record 26 of Set 5 | lompoc
# Processing Record 27 of Set 5 | poplar bluff
# Processing Record 28 of Set 5 | bundaberg
# Processing Record 29 of Set 5 | vao
# Processing Record 30 of Set 5 | glenwood springs
# Processing Record 31 of Set 5 | mozarlandia
# Processing Record 32 of Set 5 | ternate
# Processing Record 33 of Set 5 | yar-sale
# Processing Record 34 of Set 5 | natal
# Processing Record 35 of Set 5 | pangoa
# Processing Record 36 of Set 5 | khandyga
# Processing Record 37 of Set 5 | severodvinsk
# Processing Record 38 of Set 5 | port-gentil
# Processing Record 39 of Set 5 | airai
# Processing Record 40 of Set 5 | rye
# Processing Record 41 of Set 5 | mbini
# Processing Record 42 of Set 5 | khani
# Processing Record 43 of Set 5 | noumea
# City not found. Skipping...
# Processing Record 44 of Set 5 | malinovskiy
# Processing Record 45 of Set 5 | kaitangata
# City not found. Skipping...
# Processing Record 46 of Set 5 | eirunepe
# Processing Record 47 of Set 5 | thinadhoo
# Processing Record 48 of Set 5 | saint-philippe
# Processing Record 49 of Set 5 | kungurtug
# Processing Record 1 of Set 6 | olinda
# Processing Record 2 of Set 6 | greenwood
# Processing Record 3 of Set 6 | todos santos
# Processing Record 4 of Set 6 | omsukchan
# Processing Record 5 of Set 6 | manta
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 6 | isangel
# Processing Record 7 of Set 6 | post falls
# City not found. Skipping...
# Processing Record 8 of Set 6 | rorvik
# Processing Record 9 of Set 6 | la ronge
# City not found. Skipping...
# Processing Record 10 of Set 6 | swan hill
# City not found. Skipping...
# Processing Record 11 of Set 6 | honiara
# Processing Record 12 of Set 6 | wuwei
# Processing Record 13 of Set 6 | long xuyen
# Processing Record 14 of Set 6 | alvaraes
# Processing Record 15 of Set 6 | sorland
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 6 | constitucion
# Processing Record 17 of Set 6 | tianpeng
# Processing Record 18 of Set 6 | road town
# Processing Record 19 of Set 6 | auki
# Processing Record 20 of Set 6 | mascota
# Processing Record 21 of Set 6 | hamilton
# City not found. Skipping...
# Processing Record 22 of Set 6 | reconquista
# Processing Record 23 of Set 6 | libreville
# Processing Record 24 of Set 6 | kikwit
# Processing Record 25 of Set 6 | taywarah
# Processing Record 26 of Set 6 | atherton
# Processing Record 27 of Set 6 | fairbanks
# Processing Record 28 of Set 6 | ayan
# City not found. Skipping...
# Processing Record 29 of Set 6 | buraydah
# City not found. Skipping...
# Processing Record 30 of Set 6 | novikovo
# Processing Record 31 of Set 6 | llanes
# Processing Record 32 of Set 6 | bibbiena
# Processing Record 33 of Set 6 | coquimbo
# Processing Record 34 of Set 6 | cardston
# Processing Record 35 of Set 6 | lorengau
# Processing Record 36 of Set 6 | mahebourg
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | honningsvag
# City not found. Skipping...
# Processing Record 39 of Set 6 | mutata
# Processing Record 40 of Set 6 | uray
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 6 | puerto madryn
# Processing Record 42 of Set 6 | sarakhs
# Processing Record 43 of Set 6 | la orilla
# Processing Record 44 of Set 6 | santa barbara
# Processing Record 45 of Set 6 | carahue
# City not found. Skipping...
# Processing Record 46 of Set 6 | sitrah
# Processing Record 47 of Set 6 | fevik
# City not found. Skipping...
# Processing Record 48 of Set 6 | kamaishi
# Processing Record 49 of Set 6 | camacha
# Processing Record 1 of Set 7 | marawi
# Processing Record 2 of Set 7 | grodzisk wielkopolski
# Processing Record 3 of Set 7 | dakar
# Processing Record 4 of Set 7 | kohlu
# Processing Record 5 of Set 7 | liwale
# Processing Record 6 of Set 7 | atar
# City not found. Skipping...
# Processing Record 7 of Set 7 | nola
# Processing Record 8 of Set 7 | comodoro rivadavia
# Processing Record 9 of Set 7 | araouane
# Processing Record 10 of Set 7 | lima
# Processing Record 11 of Set 7 | talnakh
# Processing Record 12 of Set 7 | buala
# Processing Record 13 of Set 7 | dukhovshchina
# Processing Record 14 of Set 7 | izhma
# Processing Record 15 of Set 7 | warrington
# Processing Record 16 of Set 7 | voh
# City not found. Skipping...
# Processing Record 17 of Set 7 | beira
# Processing Record 18 of Set 7 | clyde river
# Processing Record 19 of Set 7 | abu zabad
# Processing Record 20 of Set 7 | touros
# Processing Record 21 of Set 7 | batsfjord
# Processing Record 22 of Set 7 | kutum
# Processing Record 23 of Set 7 | geraldton
# Processing Record 24 of Set 7 | barras
# Processing Record 25 of Set 7 | coihaique
# City not found. Skipping...
# Processing Record 26 of Set 7 | uvat
# Processing Record 27 of Set 7 | saldanha
# Processing Record 28 of Set 7 | yerbogachen
# Processing Record 29 of Set 7 | oswego
# Processing Record 30 of Set 7 | codrington
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 7 | sur
# Processing Record 32 of Set 7 | aykhal
# Processing Record 33 of Set 7 | saurimo
# Processing Record 34 of Set 7 | koslan
# Processing Record 35 of Set 7 | banda aceh
# Processing Record 36 of Set 7 | caohai
# Processing Record 37 of Set 7 | vostok
# Processing Record 38 of Set 7 | cayenne
# Processing Record 39 of Set 7 | flin flon
# City not found. Skipping...
# Processing Record 40 of Set 7 | roma
# Processing Record 41 of Set 7 | sandovo
# Processing Record 42 of Set 7 | saint-joseph
# Processing Record 43 of Set 7 | voskresenskoye
# Processing Record 44 of Set 7 | richards bay
# Processing Record 45 of Set 7 | lavrentiya
# Processing Record 46 of Set 7 | kavieng
# Processing Record 47 of Set 7 | ivdel
# Processing Record 48 of Set 7 | belaya gora
# Processing Record 17 of Set 9 | mbaiki
# Processing Record 18 of Set 9 | srednekolymsk
# City not found. Skipping...
# Processing Record 19 of Set 9 | lahij
# Processing Record 20 of Set 9 | murgab
# Processing Record 21 of Set 9 | sao paulo de olivenca
# Processing Record 22 of Set 9 | maun
# Processing Record 23 of Set 9 | khilok
# Processing Record 24 of Set 9 | villa carlos paz
# Processing Record 25 of Set 9 | ankazobe
# Processing Record 26 of Set 9 | orel-izumrud
# Processing Record 27 of Set 9 | togur
# Processing Record 28 of Set 9 | panaba
# Processing Record 29 of Set 9 | vardo
# City not found. Skipping...
# Processing Record 30 of Set 9 | tulum
# Processing Record 31 of Set 9 | bud
# City not found. Skipping...
# Processing Record 32 of Set 9 | tevaitoa
# Processing Record 33 of Set 9 | jasper
# Processing Record 34 of Set 9 | puerto colombia
# Processing Record 35 of Set 9 | cabo san lucas
# Processing Record 36 of Set 9 | bom jesus
# Processing Record 37 of Set 9 | moerai
# Processing Record 38 of Set 9 | okhotsk
# City not found. Skipping...
# Processing Record 39 of Set 9 | elektrogorsk
# Processing Record 40 of Set 9 | northam
# Processing Record 41 of Set 9 | bathsheba
# Processing Record 42 of Set 9 | qandala
# Processing Record 43 of Set 9 | leh
# Processing Record 44 of Set 9 | hasaki
# Processing Record 45 of Set 9 | marienburg
# Processing Record 46 of Set 9 | seguin
# Processing Record 47 of Set 9 | waitati
# Processing Record 48 of Set 9 | sturgeon falls
# Processing Record 49 of Set 9 | shingu
# Processing Record 1 of Set 10 | dakoro
# Processing Record 2 of Set 10 | buin
# Processing Record 3 of Set 10 | kirkcudbright
# Processing Record 4 of Set 10 | amga
# Processing Record 5 of Set 10 | hailar
# Processing Record 6 of Set 10 | ciudad bolivar
# Processing Record 7 of Set 10 | durango
# Processing Record 8 of Set 10 | berlevag
# Processing Record 9 of Set 10 | san francisco
# Processing Record 10 of Set 10 | rive-de-gier
# Processing Record 11 of Set 10 | inhambane
# Processing Record 12 of Set 10 | bahir dar
# Processing Record 13 of Set 10 | kichera
# Processing Record 14 of Set 10 | neijiang
# Processing Record 15 of Set 10 | chicama
# Processing Record 16 of Set 10 | sitka
# Processing Record 17 of Set 10 | skjervoy
# Processing Record 18 of Set 10 | malatya
# Processing Record 19 of Set 10 | qasigiannguit
# Processing Record 20 of Set 10 | grand gaube
# Processing Record 21 of Set 10 | oriximina
# City not found. Skipping...
# Processing Record 22 of Set 10 | pangnirtung
# Processing Record 23 of Set 10 | skelleftea
# Processing Record 24 of Set 10 | juneau
# Processing Record 25 of Set 10 | eureka
# Processing Record 26 of Set 10 | mirnyy
# Processing Record 27 of Set 10 | frontera
# Processing Record 28 of Set 10 | laizhou
# Processing Record 29 of Set 10 | bari
# Processing Record 30 of Set 10 | ardakan
# Processing Record 31 of Set 10 | manzhouli
# Processing Record 32 of Set 10 | alice springs
# Processing Record 33 of Set 10 | aguimes
# Processing Record 34 of Set 10 | charters towers
# Processing Record 35 of Set 10 | lewiston
# Processing Record 36 of Set 10 | marzuq
# Processing Record 37 of Set 10 | moron
# Processing Record 38 of Set 10 | altamirano
# Processing Record 39 of Set 10 | fare
# Processing Record 40 of Set 10 | kupang
# Processing Record 41 of Set 10 | naustdal
# Processing Record 42 of Set 10 | bagdarin
# Processing Record 43 of Set 10 | amuntai
# Processing Record 44 of Set 10 | turbat
# Processing Record 45 of Set 10 | paragominas
# Processing Record 46 of Set 10 | jabinyanah
# Processing Record 47 of Set 10 | tchibanga
# Processing Record 48 of Set 10 | dovolnoye
# City not found. Skipping...
# Processing Record 49 of Set 10 | msowero
# Processing Record 1 of Set 11 | baijiantan
# Processing Record 2 of Set 11 | havoysund
# Processing Record 3 of Set 11 | terney
# Processing Record 4 of Set 11 | wabag
# Processing Record 5 of Set 11 | eyl
# Processing Record 6 of Set 11 | cabedelo
# City not found. Skipping...
# Processing Record 7 of Set 11 | abu samrah
# Processing Record 8 of Set 11 | suleja
# Processing Record 9 of Set 11 | kubrat
# Processing Record 10 of Set 11 | bakaly
# Processing Record 11 of Set 11 | denpasar
# Processing Record 12 of Set 11 | smithers
# Processing Record 13 of Set 11 | udachnyy
# Processing Record 14 of Set 11 | boma
# Processing Record 15 of Set 11 | seoul
# City not found. Skipping...
# Processing Record 16 of Set 11 | svetlogorsk
# Processing Record 17 of Set 11 | ahipara
# Processing Record 18 of Set 11 | neuquen
# Processing Record 19 of Set 11 | jurm
# Processing Record 20 of Set 11 | kuryk
# Processing Record 21 of Set 11 | bilibino
# Processing Record 22 of Set 11 | pochutla
# City not found. Skipping...
# Processing Record 23 of Set 11 | ixtapa
# Processing Record 24 of Set 11 | sandwick
# Processing Record 25 of Set 11 | toyooka
# Processing Record 26 of Set 11 | lubao
# Processing Record 27 of Set 11 | aranos
# Processing Record 28 of Set 11 | emerald
# Processing Record 29 of Set 11 | waipawa
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Put max temps list into an array
Max_Temps_Array = np.asarray(Max_Temps)

#Conversion of max temps from Kelvin to Fahrenheight
Max_Temps_F = (Max_Temps_Array - 273.15) * 1.8 + 32

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(f"cities: {len(New_Cities)}")
print(f"Clouds: {len(Clouds)}")
print(f"Countries: {len(Countries)}")
print(f"Humidities: {len(Humidities)}")
print(f"Latitudes: {len(Latitudes)}")
print(f"Longitudes: {len(Longitudes)}")
print(f"Max Temperatures: {len(Max_Temps_F)}")
print(f"Wind Speeds: {len(Wind_Speeds)}")
print(f"Dates: {len(Dates)}")
# Out:
# cities: 519
# Clouds: 519
# Countries: 519
# Humidities: 519
# Latitudes: 519
# Longitudes: 519
# Max Temperatures: 519
# Wind Speeds: 519
# Dates: 519

# %%
Weather_DF = pd.DataFrame({'City': New_Cities,
                           'Cloudiness': Clouds,
                           'Country': Countries,
                           'Date' : Dates,
                           'Humidity': Humidities,
                           'Lat': Latitudes,
                           'Lng': Longitudes,
                           'Max Temp': Max_Temps_F,
                           'Wind Speed': Wind_Speeds})

Weather_DF.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  leningradskiy          81      RU  1571175494        83  69.38  178.42
# 1        aklavik          90      CA  1571175494        85  68.22 -135.01
# 2        rikitea           1      PF  1571175494        87 -23.12 -134.97
# 3   ponta do sol          90      BR  1571175495        44 -20.63  -46.00
# 4        ushuaia          14      AR  1571175331        53 -54.81  -68.31
#
#    Max Temp  Wind Speed
# 0    35.042       6.385
# 1    19.400       4.600
# 2    74.354       3.726
# 3    79.844       1.287
# 4    51.800       0.840

# %%
# Extracting columns needed for plotting
latitudes = Weather_DF['Lat']
max_temperatures = Weather_DF['Max Temp']
humidity = Weather_DF['Humidity']
cloudiness = Weather_DF['Cloudiness']
wind_speed = Weather_DF['Wind Speed']

# %%
# Export Data to output data CSV file

Weather_DF.to_csv(output_data_file, index_label='City_ID')

# %%
# City Count to verify we have 500 cities

Weather_DF.count()
# Out:
# City          519
# Cloudiness    519
# Country       519
# Date          519
# Humidity      519
# Lat           519
# Lng           519
# Max Temp      519
# Wind Speed    519
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# plot scatter plot 'Latitude vs. Temperature Plot'
plt.scatter(latitudes, max_temperatures, edgecolor='black', linewidth=1, marker='o', alpha=0.8, label='Cities')

# Plot Title
plt.title('City Latitude vs. Max Temperature ' + time.strftime('%x'))

# Plot X-Axis label
plt.xlabel('Latitude')

#Plot Y-Axis label
plt.ylabel('Max Temperature (F)')

#Plot grid lines
plt.grid(True)

# Save scatter plot
plt.savefig('output_data/Figure_1.png')

# Show scatter plot
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plot scatter plot 'Latitude vs. Temperature Plot'
plt.scatter(latitudes, humidity, edgecolor='black', linewidth=1, marker='o', alpha=0.8, label='Cities')

# Plot Title
plt.title('City Latitude vs. Humidity ' + time.strftime('%x'))

# Plot X-Axis label
plt.xlabel('Latitude')

#Plot Y-Axis label
plt.ylabel('Humidity (%)')

#Plot grid lines
plt.grid(True)

# Save scatter plot
plt.savefig('output_data/Figure_2.png')

# Show scatter plot
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plot scatter plot 'Latitude vs. Temperature Plot'
plt.scatter(latitudes, cloudiness, edgecolor='black', linewidth=1, marker='o', alpha=0.8, label='Cities')

# Plot Title
plt.title('City Latitude vs. Cloudiness ' + time.strftime('%x'))

# Plot X-Axis label
plt.xlabel('Latitude')

#Plot Y-Axis label
plt.ylabel('Cloudiness (%)')

#Plot grid lines
plt.grid(True)

# Save scatter plot
plt.savefig('output_data/Figure_3.png')

# Show scatter plot
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plot scatter plot 'Latitude vs. Temperature Plot'
plt.scatter(latitudes, wind_speed, edgecolor='black', linewidth=1, marker='o', alpha=0.8, label='Cities')

# Plot Title
plt.title('City Latitude vs. Wind Speed ' + time.strftime('%x'))

# Plot X-Axis label
plt.xlabel('Latitude')

#Plot Y-Axis label
plt.ylabel('Wind Speed (mph)')

#Plot grid lines
plt.grid(True)

# Save scatter plot
plt.savefig('output_data/Figure_4.png')

# Show scatter plot
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
